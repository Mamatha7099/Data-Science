# %% [markdown]
# # Introduction:
# This data set is about bank marketing campaign impact of a bank mainly through telemarketing.In this file 2 data sets are given. In the first data set i.e bank full has 45211 rows and1 columns present  and 2nd data set is bank which has taken 10% from bank full data set has 4521 and 17 columns are present..When  I concatinated these 2 data sets finally i data has come i.e Bank_db .(I given name for data) In the final data set 49732 rows and 17 columns are present.After concating 2 files basic exploration is done checking missing values outliers a nd skewness checking done .univarient,bivarient and multi varient analysis done accordingly.feature extraction and PCA done.

# %% [markdown]
# # Attribute In formation:

# %% [markdown]
# Input variables:
# age : numerical data given
#
# job : catagorical data given
#
# marital : catagorical data given .where divorced means diversed and widowed both.
#
# education: catagorical data given
#
# default:  catagorical data given.where yes means no default on credit card and yes means having default on credit card
#
# Balance:numerical data given.balance of bank account
#
# housing: : catagorical data given yes,no given.
#
# loan:: catagorical data given.yes,no given
#
# Related with the last contact of the current campaign:
# Contact: : catagorical data given. contact communication type ("cellular","telephone")
#
# Month: : catagorical data given. last contact month of year
#
# day_of_week:: catagorical data given.last contact day of the week
#
# Duration: numerical data .last contact duration, in seconds. It effects on subscription
#
# Other attributes:
# Campaign: numerical data given.Number of contacts performed during this campaign and for this client includes last contact
#
# pdays: numerical data given. (999 means client was not previously contacted)
#
# Previous:  numerical data given.number of contacts performed
#
# poutcome: catagorical data given.
#
# Outcome variable: catagorical data given.if subscription done i.e yes otherwise no.

# %%
import numpy as np                 # importing all important libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv("bank.csv")      #readind bank data set as df1
df1
# Out:
#      age;"job";"marital";"education";"default";"balance";"housing";"loan";"contact";"day";"month";"duration";"campaign";"pdays";"previous";"poutcome";"y"
# 0     30;"unemployed";"married";"primary";"no";1787;...
# 1     33;"services";"married";"secondary";"no";4789;...
# 2     35;"management";"single";"tertiary";"no";1350;...
# 3     30;"management";"married";"tertiary";"no";1476...
# 4     59;"blue-collar";"married";"secondary";"no";0;...
# ...                                                 ...
# 4516  33;"services";"married";"secondary";"no";-333;...
# 4517  57;"self-employed";"married";"tertiary";"yes";...
# 4518  57;"technician";"married";"secondary";"no";295...
# 4519  28;"blue-collar";"married";"secondary";"no";11...
# 4520  44;"entrepreneur";"single";"tertiary";"no";113...
#
# [4521 rows x 1 columns]

# %%
df1=pd.read_csv("bank.csv",sep=';',header=[0])     # normalising the file
df1
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
df2=pd.read_csv("bank-full.csv")      # reading bank full data set as df2
df2
# Out:
#       age;"job";"marital";"education";"default";"balance";"housing";"loan";"contact";"day";"month";"duration";"campaign";"pdays";"previous";"poutcome";"y"
# 0      58;"management";"married";"tertiary";"no";2143...
# 1      44;"technician";"single";"secondary";"no";29;"...
# 2      33;"entrepreneur";"married";"secondary";"no";2...
# 3      47;"blue-collar";"married";"unknown";"no";1506...
# 4      33;"unknown";"single";"unknown";"no";1;"no";"n...
# ...                                                  ...
# 45206  51;"technician";"married";"tertiary";"no";825;...
# 45207  71;"retired";"divorced";"primary";"no";1729;"n...
# 45208  72;"retired";"married";"secondary";"no";5715;"...
# 45209  57;"blue-collar";"married";"secondary";"no";66...
# 45210  37;"entrepreneur";"married";"secondary";"no";2...
#
# [45211 rows x 1 columns]

# %%
df2=pd.read_csv("bank-full.csv",sep=';',header=[0])      # normalising the file
df1
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
df=pd.concat([df1,df2])       # concating both df1 and df2 as df ( bank)
df
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       30    unemployed   married    primary      no     1787      no   no
# 1       33      services   married  secondary      no     4789     yes  yes
# 2       35    management    single   tertiary      no     1350     yes   no
# 3       30    management   married   tertiary      no     1476     yes  yes
# 4       59   blue-collar   married  secondary      no        0     yes   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %%
df.drop_duplicates()       # droping duplicates  from df data set
df
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       30    unemployed   married    primary      no     1787      no   no
# 1       33      services   married  secondary      no     4789     yes  yes
# 2       35    management    single   tertiary      no     1350     yes   no
# 3       30    management   married   tertiary      no     1476     yes  yes
# 4       59   blue-collar   married  secondary      no        0     yes   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %%
df.head()    # checking first 5 rows
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %%
df.tail()     # checking last 5 rows
# Out:
#        age           job   marital  education default  balance housing loan  \
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome    y
# 45206   cellular   17   nov       977         3     -1         0  unknown  yes
# 45207   cellular   17   nov       456         2     -1         0  unknown  yes
# 45208   cellular   17   nov      1127         5    184         3  success  yes
# 45209  telephone   17   nov       508         4     -1         0  unknown   no
# 45210   cellular   17   nov       361         2    188        11    other   no

# %%
df.columns     # checking last 5 rows
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
df.shape    # It gives columns and rows numbers
# Out:
# (49732, 17)

# %%
type(df)   # It gives type of data set
# Out:
# pandas.core.frame.DataFrame

# %%
df.info()     # It gives total information of the data set
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 49732 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        49732 non-null  int64
#  1   job        49732 non-null  object
#  2   marital    49732 non-null  object
#  3   education  49732 non-null  object
#  4   default    49732 non-null  object
#  5   balance    49732 non-null  int64
#  6   housing    49732 non-null  object
#  7   loan       49732 non-null  object
#  8   contact    49732 non-null  object
#  9   day        49732 non-null  int64
#  10  month      49732 non-null  object
#  11  duration   49732 non-null  int64
#  12  campaign   49732 non-null  int64
#  13  pdays      49732 non-null  int64
#  14  previous   49732 non-null  int64
#  15  poutcome   49732 non-null  object
#  16  y          49732 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 6.8+ MB

# %% [markdown]
# Missing values: There are no missing values in the data but -ve values given which has meaning and can also possible like -ve balance etc. So Iam not performing any filling values for that.Because it will affect data.

# %%
df.isnull().sum()    # checking is there any null values
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %%
df.describe()     # It gives  5 points values of data
# Out:
#                 age        balance           day      duration      campaign  \
# count  49732.000000   49732.000000  49732.000000  49732.000000  49732.000000
# mean      40.957472    1367.761562     15.816315    258.690179      2.766549
# std       10.615008    3041.608766      8.315680    257.743149      3.099075
# min       18.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     448.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1431.000000     21.000000    320.000000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  49732.000000  49732.000000
# mean      40.158630      0.576892
# std      100.127123      2.254838
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# ...

# %%
df.value_counts()   # checking value counts of data
# Out:
# age  job          marital  education  default  balance  housing  loan  contact    day  month  duration  campaign  pdays  previous  poutcome  y
# 57   retired      married  secondary  no       1044     no       no    telephone  11   jan    585       1          192   2         success   yes    2
# 28   management   married  tertiary   no       3694     no       yes   cellular   8    jul    70        2         -1     0         unknown   no     2
# 31   technician   single   secondary  yes      25       no       no    cellular   2    feb    381       1         -1     0         unknown   no     2
# 58   blue-collar  married  primary    no       781      yes      no    cellular   15   may    74        2         -1     0         unknown   no     2
# 28   management   single   secondary  no       171      no       no    cellular   10   mar    93        1         -1     0         unknown   yes    2
# ...

# %%
# changing columns names  of the data and given name as bank_db for the data
bank_db=df.rename(columns={"age":"Age","job":"Job","marital":"Marital_Status","education":"Education","default":"Default","balance":"Balance",
                            "housing":"Housing","loan":"Loan","contact":"Contact_Type","day":"Day","month":"Month","duration":"Duration",
                            "campaign":"Campaign","pdays":"P_Days","previous":"Previous","poutcome":"P_Outcome","y":"Y/N"})
bank_db
# Out:
#        Age           Job Marital_Status  Education Default  Balance Housing  \
# 0       30    unemployed        married    primary      no     1787      no
# 1       33      services        married  secondary      no     4789     yes
# 2       35    management         single   tertiary      no     1350     yes
# 3       30    management        married   tertiary      no     1476     yes
# 4       59   blue-collar        married  secondary      no        0     yes
# ...    ...           ...            ...        ...     ...      ...     ...
# 45206   51    technician        married   tertiary      no      825      no
# 45207   71       retired       divorced    primary      no     1729      no
# 45208   72       retired        married  secondary      no     5715      no
# 45209   57   blue-collar        married  secondary      no      668      no
# 45210   37  entrepreneur        married  secondary      no     2971      no
#
# ...

# %%
#changing categorical columns into int type which are given values in data set and given name as Bank_db.
Bank_db= bank_db.astype({"Age" : "int","Balance":"int","Day":"int","Duration":"int","Campaign":"int","P_Days":"int","Previous":"int"})

# %%
Bank_db.info()   # checking catagorical columns which changed to int data type
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 49732 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             49732 non-null  int32
#  1   Job             49732 non-null  object
#  2   Marital_Status  49732 non-null  object
#  3   Education       49732 non-null  object
#  4   Default         49732 non-null  object
#  5   Balance         49732 non-null  int32
#  6   Housing         49732 non-null  object
#  7   Loan            49732 non-null  object
#  8   Contact_Type    49732 non-null  object
#  9   Day             49732 non-null  int32
#  10  Month           49732 non-null  object
#  11  Duration        49732 non-null  int32
#  12  Campaign        49732 non-null  int32
#  13  P_Days          49732 non-null  int32
#  14  Previous        49732 non-null  int32
#  15  P_Outcome       49732 non-null  object
#  16  Y/N             49732 non-null  object
# ...

# %%
Bank_db.head()  # checking again first 5 rows of the data
# Out:
#    Age          Job Marital_Status  Education Default  Balance Housing Loan  \
# 0   30   unemployed        married    primary      no     1787      no   no
# 1   33     services        married  secondary      no     4789     yes  yes
# 2   35   management         single   tertiary      no     1350     yes   no
# 3   30   management        married   tertiary      no     1476     yes  yes
# 4   59  blue-collar        married  secondary      no        0     yes   no
#
#   Contact_Type  Day Month  Duration  Campaign  P_Days  Previous P_Outcome Y/N
# 0     cellular   19   oct        79         1      -1         0   unknown  no
# 1     cellular   11   may       220         1     339         4   failure  no
# 2     cellular   16   apr       185         1     330         1   failure  no
# 3      unknown    3   jun       199         4      -1         0   unknown  no
# 4      unknown    5   may       226         1      -1         0   unknown  no

# %% [markdown]
# BINNING

# %%
bin_labels_3=["young","middle_age","old"]    #  binning for the Age column to understand more,giving labels
Bank_db['Age_qcut_bin']=pd.qcut(Bank_db['Age'], # using q cut binning
                        q=[0,.3,.5,1],
                        labels=bin_labels_3)
Bank_db[['Age','Age_qcut_bin']]            # creating new column as Age_qcut_bin.
# Out:
#        Age Age_qcut_bin
# 0       30        young
# 1       33        young
# 2       35   middle_age
# 3       30        young
# 4       59          old
# ...    ...          ...
# 45206   51          old
# 45207   71          old
# 45208   72          old
# 45209   57          old
# 45210   37   middle_age
#
# [49732 rows x 2 columns]

# %%
Bank_db.head()    # checking head of the data
# Out:
#    Age          Job Marital_Status  Education Default  Balance Housing Loan  \
# 0   30   unemployed        married    primary      no     1787      no   no
# 1   33     services        married  secondary      no     4789     yes  yes
# 2   35   management         single   tertiary      no     1350     yes   no
# 3   30   management        married   tertiary      no     1476     yes  yes
# 4   59  blue-collar        married  secondary      no        0     yes   no
#
#   Contact_Type  Day Month  Duration  Campaign  P_Days  Previous P_Outcome Y/N  \
# 0     cellular   19   oct        79         1      -1         0   unknown  no
# 1     cellular   11   may       220         1     339         4   failure  no
# 2     cellular   16   apr       185         1     330         1   failure  no
# 3      unknown    3   jun       199         4      -1         0   unknown  no
# 4      unknown    5   may       226         1      -1         0   unknown  no
#
#   Age_qcut_bin
# 0        young
# ...

# %%
Bank_db.info()   # checking information of the data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 49732 entries, 0 to 45210
# Data columns (total 18 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             49732 non-null  int32
#  1   Job             49732 non-null  object
#  2   Marital_Status  49732 non-null  object
#  3   Education       49732 non-null  object
#  4   Default         49732 non-null  object
#  5   Balance         49732 non-null  int32
#  6   Housing         49732 non-null  object
#  7   Loan            49732 non-null  object
#  8   Contact_Type    49732 non-null  object
#  9   Day             49732 non-null  int32
#  10  Month           49732 non-null  object
#  11  Duration        49732 non-null  int32
#  12  Campaign        49732 non-null  int32
#  13  P_Days          49732 non-null  int32
#  14  Previous        49732 non-null  int32
#  15  P_Outcome       49732 non-null  object
#  16  Y/N             49732 non-null  object
# ...

# %% [markdown]
# Checking  skewness:

# %%
Bank_db.skew()   # checking skewness of hte data
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_8424\387370570.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   Bank_db.skew()   # checking skewness of hte data
# Age          0.686033
# Balance      8.204429
# Day          0.093154
# Duration     3.109530
# Campaign     4.884266
# P_Days       2.624838
# Previous    40.783648
# dtype: float64

# %% [markdown]
# Age ,balance ,duration , campaign, p_days,prevous  are right (+) skew
# Day column is normally distributed

# %%
sns.displot(Bank_db["Age"],kind="kde")    # checking skewness of age column using displot
plt.title("Age skew")                    # giving title and x axis
plt.xlabel("Age")
# Out:
# Text(0.5, 6.79999999999999, 'Age')

# %%
#Bank_db["Age"]=np.log(Bank_db["Age"])

# %%
sns.displot(Bank_db["Balance"],kind="kde")   # checking skewness of  balance
plt.title(" skew of Balnce")                  # giving title and x axis
plt.xlabel("Balance")
# Out:
# Text(0.5, 6.79999999999999, 'Balance')

# %%
#Bank_db["Balance"]=np.log(Bank_db["Balance"])

# %%
sns.displot(Bank_db["Day"],kind="kde")    # checking skewness of day
plt.title('skewness of Day')               # giving title as skewness of day  and x axis as day
plt.xlabel("Day")
# Out:
# Text(0.5, 6.79999999999999, 'Day')

# %%
#Bank_db["Day"]=np.log(Bank_db["Day"])

# %%
sns.displot(Bank_db["Duration"],kind="kde")     # checking skewness of duration
plt.title("skewness of aDuration")               # giving title as skewness of duration and on x axis as Duration
plt.xlabel('Duration')
# Out:
# Text(0.5, 6.79999999999999, 'Duration')

# %%
#Bank_db["Duration"]=np.log(Bank_db["Duration"])

# %%
sns.displot(Bank_db["Campaign"],kind="kde")  # checking skewness of campaign
plt.title("skewness of Campaign")            # giving title as skewness of campaign and x axis as Campaign
plt.xlabel("Campaign")
# Out:
# Text(0.5, 6.79999999999999, 'Campaign')

# %%
#Bank_db["Campagin"]=np.log(Bank_db["Campaign"])

# %%
sns.displot(Bank_db["P_Days"],kind="kde")    # checking  skewness of p days
plt.title(" skewness of P_Days")             # giving title as skewness of P_Days and x axis as P_Days
plt.xlabel("P_Days")
# Out:
# Text(0.5, 6.79999999999999, 'P_Days')

# %%
#Bank_db["P_Days"]=np.log(Bank_db["P_Days"])

# %%
sns.displot(Bank_db["Previous"],kind="kde")      # checking skewness of previous
plt.title("skewness of Previous")                #giving title as skewness of previous and x axis as previous
plt.xlabel("Previous")
# Out:
# Text(0.5, 6.79999999999999, 'Previous')

# %%
#Bank_db["Previous"]=np.log(Bank_db["Previous"])

# %% [markdown]
# Checked skewness of data, only numerical columns like Age, Balance, Day, Duration, Campaign, P_Days are given remaing columns are catogorical. for numerical columns skewness is present mostly +ve skew except day column ,it is nearly symmetric. Here log transformation can be done but the values which we get after log transformation  will effect our result and also in SQL workbench also. so I have not transforming skew data.

# %% [markdown]
# # Outliers

# %%
plt.figure(figsize=(20,20))        # arranging plot size
sns.boxplot(data=Bank_db)           # plotting boxplot for outliers in the data
plt.title("Boxplot of Bank_db")     # giving title
# Out:
# Text(0.5, 1.0, 'Boxplot of Bank_db')

# %%
#from scipy import stats

# %%
#z = np.abs(stats.zscore(Bank_db["Age"]))
#sns.histplot(data = z, kde = True)
#plt.show()

# %%
#z = np.abs(stats.zscore(Bank_db["Day"]))
#sns.histplot(data = z, kde = True)
#plt.show()

# %%
#z = np.abs(stats.zscore(Bank_db["Campaign"]))
#sns.histplot(data = z, kde = True)
#plt.show()

# %%
#z = np.abs(stats.zscore(Bank_db["Previous"]))
#sns.histplot(data = z, kde = True)
#plt.show()

# %% [markdown]
# For outliers boxplot used.Here also we can use zcore and remaining methods to normalize outliers but data is changing .So with out changing the data no actions taken on outliers.

# %%
Bank_db.to_csv("Bank_1.csv")  #converting Bank_db to csv file which later it converts to mysql.

# %% [markdown]
# # Univarient analysis

# %%
Bank_db["Age"].value_counts()   # counting values of age column
# Out:
# 32    2309
# 31    2195
# 34    2161
# 33    2158
# 35    2074
#       ...
# 92       2
# 90       2
# 95       2
# 88       2
# 94       1
# Name: Age, Length: 77, dtype: int64

# %%
Bank_db.columns  # checking column names
# Out:
# Index(['Age', 'Job', 'Marital_Status', 'Education', 'Default', 'Balance',
#        'Housing', 'Loan', 'Contact_Type', 'Day', 'Month', 'Duration',
#        'Campaign', 'P_Days', 'Previous', 'P_Outcome', 'Y/N', 'Age_qcut_bin'],
#       dtype='object')

# %%
plt.figure(figsize=(12,12))             # arranging plot size
sns.distplot(Bank_db['Age'])     #using distplot by taking Age on x axis
plt.title("dist plot of Age")          # giving title and x axis name
plt.xlabel("Age")
# Out:
# C:\Users\hp\anaconda3 .1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 0, 'Age')

# %% [markdown]
#  It is numerical data. I have taken distplot to understand age column.Maximum data is falling in the range of 20 to 60.That is more members from the data set are young and middle age people ,who are taking loans from the bank and bank also consulting those age people more.From value_counts it is clear that more members are 32 years old.

# %%
Bank_db["Job"].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0          unemployed
# 1            services
# 2          management
# 3          management
# 4         blue-collar
#              ...
# 45206      technician
# 45207         retired
# 45208         retired
# 45209     blue-collar
# 45210    entrepreneur
# Name: Job, Length: 49732, dtype: object>

# %%
plt.figure(figsize=(15,15))             # arranging plot size
sns.countplot(data=Bank_db,x='Job')     #using countplot by taking job on x axis
plt.title("Count plot of Job")          # giving title and x axis name
plt.xlabel("Job")
# Out:
# Text(0.5, 0, 'Job')

# %% [markdown]
# Here done count plot of job because it is catagorical data.highest members applying for loan and bank also consulting  blue-collar later management  job holders

# %%
Bank_db["Default"].value_counts()    # counting values in default column
# Out:
# no     48841
# yes      891
# Name: Default, dtype: int64

# %%
sns.countplot(data=Bank_db,x="Default")  # plotting countplot
plt.title("count plot of default")        # giving title and x label name as default
plt.xlabel("Default")
# Out:
# Text(0.5, 0, 'Default')

# %% [markdown]
# It is catagorical data. From the value_counts it is clear that default no is more means default in credit is NO.48841 members are no dafault in credit and 891 are yes means having default in credit.

# %%
Bank_db["Marital_Status"].value_counts()    #checking values in marital status
# Out:
# married     30011
# single      13986
# divorced     5735
# Name: Marital_Status, dtype: int64

# %%
sns.countplot(data=Bank_db,x="Marital_Status")   #plotting countplot
plt.title("count plot of Marital_status")      # giving title for the plot and x axis as marital_status
plt.xlabel("Marital_Status")
# Out:
# Text(0.5, 0, 'Marital_Status')

# %% [markdown]
# It is also catagorical data. From the value counts married people arw 30011,single are 13986 and divorced or widowed so from the count plot it is clear that married people are more.

# %%
Bank_db["Education"].value_counts()     # counting values fro education
# Out:
# secondary    25508
# tertiary     14651
# primary       7529
# unknown       2044
# Name: Education, dtype: int64

# %%
sns.countplot(data=Bank_db,x="Education")     # plotting countplot
plt.title("countplot of education")      # giving title and x axis name
plt.xlabel("Education")
# Out:
# Text(0.5, 0, 'Education')

# %% [markdown]
# This is also catagorical data.so using countplot hence it is clear that secondary education done people are more . From value counts 25508 members done secondary education and least for unknown members i.e 2044 members.

# %%
Bank_db["Balance"].value_counts()    # counting values
# Out:
# 0        3871
# 1         210
# 2         180
# 4         152
# 3         142
#          ...
# 11310       1
# 6671        1
# 1302        1
# 2922        1
# 14204       1
# Name: Balance, Length: 7168, dtype: int64

# %%
sns.distplot(Bank_db['Balance'])       # plotting distplot
plt.title ("distplot of balance")      # giving title name and x axis name
plt.xlabel("Balance")
# Out:
# C:\Users\hp\anaconda3 .1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 0, 'Balance')

# %% [markdown]
# This is numerical data. I have taken distplot .From the maximum data is less than 5,000.

# %%
Bank_db["Housing"].value_counts()   # checking values
# Out:
# yes    27689
# no     22043
# Name: Housing, dtype: int64

# %%
sns.countplot(data=Bank_db,x="Housing")    # plotting countplot
plt.title(" countplot of Housing")         # giving title and x axis name
plt.xlabel("Housing")
# Out:
# Text(0.5, 0, 'Housing')

# %% [markdown]
# It is catagorical data . so using countplot ,by vale counts more members having yes i.e having housing loan.27689 are having housing loan and 22043 are not having housing loan i.e NO.

# %%
Bank_db["Loan"].value_counts()      # checking values in loan column
# Out:
# no     41797
# yes     7935
# Name: Loan, dtype: int64

# %%
sns.countplot(data=Bank_db,x="Loan")    # plotting countplot
plt.title("countplot of Loan")          # giving title and x label name as loan
plt.xlabel("Loan")
# Out:
# Text(0.5, 0, 'Loan')

# %% [markdown]
# It is also catagorical data.so used countplot ,by the plot most of the members i.e 41797 people not have personal loan.peole 7935 are having personal loan.

# %%
Bank_db["Contact_Type"].value_counts()    # checking values from contact type column
# Out:
# cellular     32181
# unknown      14344
# telephone     3207
# Name: Contact_Type, dtype: int64

# %%
sns.countplot(data=Bank_db,x="Contact_Type")    # plotting countplot
plt.title("countplot of Contact_Type")          # giving title and x axis name as contact type
plt.xlabel("Contact_Type")
# Out:
# Text(0.5, 0, 'Contact_Type')

# %% [markdown]
# It is catagorical data. Used countplot ,by the plot more members given cellular number as contact and less members given telephone number. 32181 members given cellular contact number and 14344 are given unknown contact and 3207 members given telephone contact.

# %%
Bank_db["Day"].value_counts()     # checking value count
# Out:
# 20    3009
# 18    2534
# 21    2224
# 17    2130
# 6     2119
# 5     2091
# 14    2043
# 8     2022
# 28    2011
# 7     2007
# 19    1958
# 29    1920
# 15    1877
# 12    1754
# 13    1751
# 30    1734
# 9     1724
# 11    1631
# 4     1584
# 16    1579
# 2     1407
# 27    1234
# 3     1184
# 26    1145
# 23    1041
# 22     991
# 25     920
# 31     702
# 10     574
# 24     483
# 1      349
# Name: Day, dtype: int64

# %%
import datetime

# %%
sns.distplot(Bank_db["Day"])
# Out:
# C:\Users\hp\anaconda3 .1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Day', ylabel='Density'>

# %%
Bank_db["Month"].value_counts()    # checking values
# Out:
# may    15164
# jul     7601
# aug     6880
# jun     5872
# nov     4359
# apr     3225
# feb     2871
# jan     1551
# oct      818
# sep      631
# mar      526
# dec      234
# Name: Month, dtype: int64

# %%
sns.countplot(data=Bank_db,x="Month")    #plotting count plot of month
plt.title("countplot of Month")          # giving title and x axis
plt.xlabel("Month")
# Out:
# Text(0.5, 0, 'Month')

# %% [markdown]
# This is catagorical data.using countplot,by plot in the month of may most of the members contacted i.e 15164.

# %%
Bank_db["Duration"].value_counts() # checking values
# Out:
# 124     204
# 104     200
# 90      197
# 89      196
# 121     195
#        ...
# 1331      1
# 1508      1
# 1833      1
# 1545      1
# 1556      1
# Name: Duration, Length: 1573, dtype: int64

# %%
sns.distplot(Bank_db["Duration"])   # plotting distplot
plt.title("distplot of Duration")    # giving title and x axis name as duration
plt.xlabel("Duration")
# Out:
# C:\Users\hp\anaconda3 .1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 0, 'Duration')

# %% [markdown]
# This is numerical data so distplot is using. most of the contact time in sec areless than 300 sec.

# %%
Bank_db["Campaign"].value_counts()     # checking value in campaign
# Out:
# 1     19278
# 2     13769
# 3      6079
# 4      3847
# 5      1931
# 6      1446
# 7       810
# 8       596
# 9       357
# 10      293
# 11      223
# 12      176
# 13      150
# 14      103
# 15       93
# 16       87
# 17       76
# 18       58
# 19       47
# 20       46
# 21       37
# 25       26
# 22       25
# 23       24
# 24       23
# 28       19
# 29       17
# 31       13
# 26       13
# 32       11
# 27       10
# 30        9
# 33        6
# 34        5
# 36        4
# 35        4
# 38        3
# 43        3
# 50        3
# 37        2
# 41        2
# 44        2
# 55        1
# 46        1
# 58        1
# 63        1
# 51        1
# 39        1
# Name: Campaign, dtype: int64

# %%
sns.distplot(Bank_db['Campaign'])    #plotting distplot  
plt.title("distplot of campaign")    # giving title and x axis as campaign
plt.xlabel("Campaign")
# Out:
# C:\Users\hp\anaconda3 .1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 0, 'Campaign')

# %% [markdown]
# This is numerical data used distplot .

# %%
Bank_db["P_Days"].value_counts()   #checking values
# Out:
# -1      40659
#  182      190
#  92       159
#  183      146
#  91       137
#         ...
#  595        1
#  626        1
#  667        1
#  421        1
#  530        1
# Name: P_Days, Length: 559, dtype: int64

# %%
sns.distplot(Bank_db["P_Days"])   # plotting distplot
plt.title("distplot of p_Days")
plt.xlabel("P_Days")              # giving title and x axis
# Out:
# C:\Users\hp\anaconda3 .1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 0, 'P_Days')

# %% [markdown]
# This is numerical data ,so used distplot.most of the member values are -1.ie.40659 members contacted value is -1.

# %%
Bank_db["Previous"].value_counts()    # checking values
# Out:
# 0      40659
# 1       3058
# 2       2299
# 3       1255
# 4        792
# 5        506
# 6        302
# 7        227
# 8        147
# 9        102
# 10        71
# 11        68
# 12        49
# 13        39
# 15        21
# 14        21
# 17        16
# 16        13
# 19        12
# 20         9
# 23         9
# 22         7
# 18         7
# 24         6
# 25         5
# 27         5
# 29         4
# 21         4
# 30         3
# 28         2
# 38         2
# 37         2
# 26         2
# 51         1
# 275        1
# 58         1
# 32         1
# 40         1
# 55         1
# 35         1
# 41         1
# Name: Previous, dtype: int64

# %%
sns.distplot(Bank_db["Previous"])   # plotting distplot
plt.title("distplot of Previous")
plt.xlabel("Previous")              # giving title and x axis
# Out:
# C:\Users\hp\anaconda3 .1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 0, 'Previous')

# %% [markdown]
# This is numerical data,so distplot is used. most of the members not taken much contacts before the campaign.

# %%
Bank_db["P_Outcome"].value_counts()   #checking vales
# Out:
# unknown    40664
# failure     5391
# other       2037
# success     1640
# Name: P_Outcome, dtype: int64

# %%
sns.countplot(data=Bank_db,x="P_Outcome")     #plotting countplot
plt.title("countplot of P_Outcome")            #giving title and x axis
plt.xlabel("P_Outcome")
# Out:
# Text(0.5, 0, 'P_Outcome')

# %% [markdown]
# This is catagi=orical data ,so countplot is used.from the plot very less people contact done successfully.i.e 1640

# %%
Bank_db["Y/N"].value_counts()   # checking values
# Out:
# no     43922
# yes     5810
# Name: Y/N, dtype: int64

# %%
sns.countplot(data=bank_db,x="Y/N")     #plotting countplot
plt.title("countplot of Y/N")           #giving title and name
plt.xlabel("Y/N")
# Out:
# Text(0.5, 0, 'Y/N')

# %% [markdown]
# It is catagorical data ,so countplot used .From the plot very less i.e 5810 members only done their subsciption means YES. remaining 43922 members not done subscription

# %% [markdown]
# # Bivarient analysis

# %%
Bank_db.head(2)  # cheking first 2 rows of the data.
# Out:
#    Age         Job Marital_Status  Education Default  Balance Housing Loan  \
# 0   30  unemployed        married    primary      no     1787      no   no
# 1   33    services        married  secondary      no     4789     yes  yes
#
#   Contact_Type  Day Month  Duration  Campaign  P_Days  Previous P_Outcome Y/N  \
# 0     cellular   19   oct        79         1      -1         0   unknown  no
# 1     cellular   11   may       220         1     339         4   failure  no
#
#   Age_qcut_bin
# 0        young
# 1        young

# %%
plt.figure(figsize=(15,15))
sns.scatterplot(data=Bank_db,x='Job',y='Balance')    # plotting scatterplot
plt.title("job vs balance")                          # giving title and x and y label
plt.xlabel("Job")
plt.ylabel("Balance")
# Out:
# Text(0, 0.5, 'Balance')

# %% [markdown]
# It is showig mamagement job members having little high balance compare to remaing.

# %%
sns.scatterplot(data=Bank_db,x='Marital_Status',y='Balance')    #plotting scatterplot
plt.title("marital_status vs balance")                         #  giving title and x and y label
plt.xlabel("Marital_Status")
plt.ylabel("Balance")
# Out:
# Text(0, 0.5, 'Balance')

# %% [markdown]
# From this plot married people have more balance compare to remaining.

# %%
sns.countplot(data=Bank_db,x='Marital_Status',hue='Housing')  #plotting countplot
plt.title("Marital_status vs housing")                         # giving title and x and y label
plt.xlabel("Marital_Status")
# Out:
# Text(0.5, 0, 'Marital_Status')

# %% [markdown]
# From the plot married people are more in data and married people are having more house loan.

# %%
sns.countplot(data=Bank_db,x='Marital_Status',hue='Loan') #plotting countplot
plt.title("Marital_status vs Loan")                         # giving title and x and y label
plt.xlabel("Marital_Status")
# Out:
# Text(0.5, 0, 'Marital_Status')

# %% [markdown]
# As you see more married people are having  more personal loan .

# %%
plt.figure(figsize=(15,15))
sns.countplot(data=Bank_db,x='Job',hue='Housing') #plotting countplot
plt.title("Job vs housing")                         # giving title and x and y label
plt.xlabel("Job")
# Out:
# Text(0.5, 0, 'Job')

# %% [markdown]
# bluecollar  job are more in data and having more housing loan.

# %%
plt.figure(figsize=(15,15))
sns.countplot(data=Bank_db,x='Job',hue='Loan') #plotting countplot
plt.title("Job vs Loan")                         # giving title and x and y label
plt.xlabel("Job")
# Out:
# Text(0.5, 0, 'Job')

# %% [markdown]
# as management job holders having less housing and personal loan compare to others.blue collar job holders are taking more loan.

# %%
sns.countplot(data=Bank_db,x='Education',hue='Loan') #plotting countplot
plt.title("Education vs Loan")                         # giving title and x and y label
plt.xlabel("education")
# Out:
# Text(0.5, 0, 'education')

# %% [markdown]
# In the data set secondary education people are more and taking personal loan is less.

# %%
sns.countplot(data=Bank_db,x='Marital_Status',hue='Y/N') #plotting countplot
plt.title("Marital_status vs Y/N")                         # giving title and x and y label
plt.xlabel("Marital_Status")
plt.ylabel("Y/N")
# Out:
# Text(0, 0.5, 'Y/N')

# %% [markdown]
# compared data many married people are not taken subsciption.but compare to others more.

# %%
sns.scatterplot(data=Bank_db,x="Y/N",y="Campaign")    #plotting scatterplot
plt.title("Y/N vs Campaign")
plt.xlabel("Y/N")                                       #giving title and x and y label
plt.ylabel("Campaign")
# Out:
# Text(0, 0.5, 'Campaign')

# %% [markdown]
# After campaigning many times also many members are not subscripted.

# %% [markdown]
# # Multivarient Analysis

# %%
# Control figure size 
plt.rcParams['figure.figsize'] = [10,10]

# use the scatterplot function to build the bubble map
sns.scatterplot(data=Bank_db, x="Job", y="Age", size="Marital_Status",hue= "Balance",alpha = 0.5,sizes=(10,1000))
# Add titles (main and on axis)
plt.xlabel("Job")
plt.ylabel("Age")
# show the graph
plt.show()

# %%
sns.boxplot(data =Bank_db,x='P_Outcome',y="Campaign",hue="Y/N") #plotting boxplot
plt.title("P_Outcomevs Campaign,Y/N")                            # giving title and x,y labels
plt.xlabel("p_Outcome")
plt.ylabel("Campaign")
# Out:
# Text(0, 0.5, 'Campaign')

# %% [markdown]
# even campaign also success is very less

# %% [markdown]
# #  Feature Engineering

# %%
import pandas as pd                                #importing library
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()                                         #doing feature ingineering on job column
Bank_db["Label Encoding_job"]=le.fit_transform(Bank_db["Job"])
Bank_db
# Out:
#        Age           Job Marital_Status  Education Default  Balance Housing  \
# 0       30    unemployed        married    primary      no     1787      no
# 1       33      services        married  secondary      no     4789     yes
# 2       35    management         single   tertiary      no     1350     yes
# 3       30    management        married   tertiary      no     1476     yes
# 4       59   blue-collar        married  secondary      no        0     yes
# ...    ...           ...            ...        ...     ...      ...     ...
# 45206   51    technician        married   tertiary      no      825      no
# 45207   71       retired       divorced    primary      no     1729      no
# 45208   72       retired        married  secondary      no     5715      no
# 45209   57   blue-collar        married  secondary      no      668      no
# 45210   37  entrepreneur        married  secondary      no     2971      no
#
# ...

# %%
le = LabelEncoder()                                         #doing feature ingineering on housing column
Bank_db["Label Encoding_housing"]=le.fit_transform(Bank_db['Housing'])
Bank_db
# Out:
#        Age           Job Marital_Status  Education Default  Balance Housing  \
# 0       30    unemployed        married    primary      no     1787      no
# 1       33      services        married  secondary      no     4789     yes
# 2       35    management         single   tertiary      no     1350     yes
# 3       30    management        married   tertiary      no     1476     yes
# 4       59   blue-collar        married  secondary      no        0     yes
# ...    ...           ...            ...        ...     ...      ...     ...
# 45206   51    technician        married   tertiary      no      825      no
# 45207   71       retired       divorced    primary      no     1729      no
# 45208   72       retired        married  secondary      no     5715      no
# 45209   57   blue-collar        married  secondary      no      668      no
# 45210   37  entrepreneur        married  secondary      no     2971      no
#
# ...

# %%
le = LabelEncoder()                                         #doing feature ingineering on loan column
Bank_db["Label Encoding_Loan"]=le.fit_transform(Bank_db["Loan"])
Bank_db
# Out:
#        Age           Job Marital_Status  Education Default  Balance Housing  \
# 0       30    unemployed        married    primary      no     1787      no
# 1       33      services        married  secondary      no     4789     yes
# 2       35    management         single   tertiary      no     1350     yes
# 3       30    management        married   tertiary      no     1476     yes
# 4       59   blue-collar        married  secondary      no        0     yes
# ...    ...           ...            ...        ...     ...      ...     ...
# 45206   51    technician        married   tertiary      no      825      no
# 45207   71       retired       divorced    primary      no     1729      no
# 45208   72       retired        married  secondary      no     5715      no
# 45209   57   blue-collar        married  secondary      no      668      no
# 45210   37  entrepreneur        married  secondary      no     2971      no
#
# ...

# %%
le = LabelEncoder()                                                      #doing label encoding on marital_status
Bank_db["Label Encoding_Marital_Status"]=le.fit_transform(Bank_db["Marital_Status"])
Bank_db
# Out:
#        Age           Job Marital_Status  Education Default  Balance Housing  \
# 0       30    unemployed        married    primary      no     1787      no
# 1       33      services        married  secondary      no     4789     yes
# 2       35    management         single   tertiary      no     1350     yes
# 3       30    management        married   tertiary      no     1476     yes
# 4       59   blue-collar        married  secondary      no        0     yes
# ...    ...           ...            ...        ...     ...      ...     ...
# 45206   51    technician        married   tertiary      no      825      no
# 45207   71       retired       divorced    primary      no     1729      no
# 45208   72       retired        married  secondary      no     5715      no
# 45209   57   blue-collar        married  secondary      no      668      no
# 45210   37  entrepreneur        married  secondary      no     2971      no
#
# ...

# %%
le = LabelEncoder()                                         #doing feature ingineering on education column
Bank_db["Label Encoding_education"]=le.fit_transform(Bank_db["Education"])
Bank_db
# Out:
#        Age           Job Marital_Status  Education Default  Balance Housing  \
# 0       30    unemployed        married    primary      no     1787      no
# 1       33      services        married  secondary      no     4789     yes
# 2       35    management         single   tertiary      no     1350     yes
# 3       30    management        married   tertiary      no     1476     yes
# 4       59   blue-collar        married  secondary      no        0     yes
# ...    ...           ...            ...        ...     ...      ...     ...
# 45206   51    technician        married   tertiary      no      825      no
# 45207   71       retired       divorced    primary      no     1729      no
# 45208   72       retired        married  secondary      no     5715      no
# 45209   57   blue-collar        married  secondary      no      668      no
# 45210   37  entrepreneur        married  secondary      no     2971      no
#
# ...

# %%
le = LabelEncoder()                                         #doing feature ingineering on month column
Bank_db["Label Encoding_month"]=le.fit_transform(Bank_db["Month"])
Bank_db
# Out:
#        Age           Job Marital_Status  Education Default  Balance Housing  \
# 0       30    unemployed        married    primary      no     1787      no
# 1       33      services        married  secondary      no     4789     yes
# 2       35    management         single   tertiary      no     1350     yes
# 3       30    management        married   tertiary      no     1476     yes
# 4       59   blue-collar        married  secondary      no        0     yes
# ...    ...           ...            ...        ...     ...      ...     ...
# 45206   51    technician        married   tertiary      no      825      no
# 45207   71       retired       divorced    primary      no     1729      no
# 45208   72       retired        married  secondary      no     5715      no
# 45209   57   blue-collar        married  secondary      no      668      no
# 45210   37  entrepreneur        married  secondary      no     2971      no
#
# ...

# %%
le = LabelEncoder()                                         #doing feature ingineering on Y/N column
Bank_db["Label Encoding_Y/N"]=le.fit_transform(Bank_db["Y/N"])
Bank_db
# Out:
#        Age           Job Marital_Status  Education Default  Balance Housing  \
# 0       30    unemployed        married    primary      no     1787      no
# 1       33      services        married  secondary      no     4789     yes
# 2       35    management         single   tertiary      no     1350     yes
# 3       30    management        married   tertiary      no     1476     yes
# 4       59   blue-collar        married  secondary      no        0     yes
# ...    ...           ...            ...        ...     ...      ...     ...
# 45206   51    technician        married   tertiary      no      825      no
# 45207   71       retired       divorced    primary      no     1729      no
# 45208   72       retired        married  secondary      no     5715      no
# 45209   57   blue-collar        married  secondary      no      668      no
# 45210   37  entrepreneur        married  secondary      no     2971      no
#
# ...

# %%
Bank_db.head()
# Out:
#    Age          Job Marital_Status  Education Default  Balance Housing Loan  \
# 0   30   unemployed        married    primary      no     1787      no   no
# 1   33     services        married  secondary      no     4789     yes  yes
# 2   35   management         single   tertiary      no     1350     yes   no
# 3   30   management        married   tertiary      no     1476     yes  yes
# 4   59  blue-collar        married  secondary      no        0     yes   no
#
#   Contact_Type  Day  ... P_Outcome  Y/N  Age_qcut_bin  Label Encoding_job  \
# 0     cellular   19  ...   unknown   no         young                  10
# 1     cellular   11  ...   failure   no         young                   7
# 2     cellular   16  ...   failure   no    middle_age                   4
# 3      unknown    3  ...   unknown   no         young                   4
# 4      unknown    5  ...   unknown   no           old                   1
#
# ...

# %%
Bank_db.info()  #gives information of data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 49732 entries, 0 to 45210
# Data columns (total 25 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Age                            49732 non-null  int32
#  1   Job                            49732 non-null  object
#  2   Marital_Status                 49732 non-null  object
#  3   Education                      49732 non-null  object
#  4   Default                        49732 non-null  object
#  5   Balance                        49732 non-null  int32
#  6   Housing                        49732 non-null  object
#  7   Loan                           49732 non-null  object
#  8   Contact_Type                   49732 non-null  object
#  9   Day                            49732 non-null  int32
#  10  Month                          49732 non-null  object
#  11  Duration                       49732 non-null  int32
# ...

# %%
num_cols = Bank_db.select_dtypes(include='int64').columns #changing columns into numerical

# %%
numerical=['Age','Balance','Day','Duration','Campaign','P_Days','Previous','Label Encoding_month',"Label Encoding_Y/N","Label Encoding_education",
                "Label Encoding_Marital_Status","Label Encoding_Loan",   "Label Encoding_housing","Label Encoding_job"]
               # arranging numerical and catagorical columns in list
catagorical=['Job','Marital_Status','Education','Default','Housing','Loan','Contact_Type','Month','P_Outcome']
Bank_db
# Out:
#        Age           Job Marital_Status  Education Default  Balance Housing  \
# 0       30    unemployed        married    primary      no     1787      no
# 1       33      services        married  secondary      no     4789     yes
# 2       35    management         single   tertiary      no     1350     yes
# 3       30    management        married   tertiary      no     1476     yes
# 4       59   blue-collar        married  secondary      no        0     yes
# ...    ...           ...            ...        ...     ...      ...     ...
# 45206   51    technician        married   tertiary      no      825      no
# 45207   71       retired       divorced    primary      no     1729      no
# 45208   72       retired        married  secondary      no     5715      no
# 45209   57   blue-collar        married  secondary      no      668      no
# 45210   37  entrepreneur        married  secondary      no     2971      no
#
# ...

# %%
Bank_db[numerical].head()   #checking only numeriacl columns
# Out:
#    Age  Balance  Day  Duration  Campaign  P_Days  Previous  \
# 0   30     1787   19        79         1      -1         0
# 1   33     4789   11       220         1     339         4
# 2   35     1350   16       185         1     330         1
# 3   30     1476    3       199         4      -1         0
# 4   59        0    5       226         1      -1         0
#
#    Label Encoding_month  Label Encoding_Y/N  Label Encoding_education  \
# 0                    10                   0                         0
# 1                     8                   0                         1
# 2                     0                   0                         2
# 3                     6                   0                         2
# 4                     8                   0                         1
#
#    Label Encoding_Marital_Status  Label Encoding_Loan  Label Encoding_housing  \
# 0                              1                    0                       0
# ...

# %%
#importing library standardscaler


from sklearn.preprocessing import StandardScaler
X=Bank_db.copy()
scaler=StandardScaler()
X[numerical]=scaler.fit_transform(X[numerical])
X.head()
# Out:
#         Age          Job Marital_Status  Education Default   Balance Housing  \
# 0 -1.032273   unemployed        married    primary      no  0.137836      no
# 1 -0.749651     services        married  secondary      no  1.124823     yes
# 2 -0.561237   management         single   tertiary      no -0.005840     yes
# 3 -1.032273   management        married   tertiary      no  0.035586     yes
# 4  1.699736  blue-collar        married  secondary      no -0.449688     yes
#
#   Loan Contact_Type       Day  ... P_Outcome  Y/N  Age_qcut_bin  \
# 0   no     cellular  0.382857  ...   unknown   no         young
# 1  yes     cellular -0.579191  ...   failure   no         young
# 2   no     cellular  0.022089  ...   failure   no    middle_age
# 3  yes      unknown -1.541238  ...   unknown   no         young
# 4   no      unknown -1.300726  ...   unknown   no           old
#
#    Label Encoding_job  Label Encoding_housing Label Encoding_Loan  \
# ...

# %%
X[numerical].head()# checking numerical data first 5 rows
# Out:
#         Age   Balance       Day  Duration  Campaign    P_Days  Previous  \
# 0 -1.032273  0.137836  0.382857 -0.697175  -0.57003 -0.411068 -0.255849
# 1 -0.749651  1.124823 -0.579191 -0.150113  -0.57003  2.984650  1.518132
# 2 -0.561237 -0.005840  0.022089 -0.285908  -0.57003  2.894763  0.187646
# 3 -1.032273  0.035586 -1.541238 -0.231590   0.39801 -0.411068 -0.255849
# 4  1.699736 -0.449688 -1.300726 -0.126834  -0.57003 -0.411068 -0.255849
#
#    Label Encoding_month  Label Encoding_Y/N  Label Encoding_education  \
# 0              1.488595           -0.363703                 -1.638131
# 1              0.823365           -0.363703                 -0.301327
# 2             -1.837556           -0.363703                  1.035478
# 3              0.158135           -0.363703                  1.035478
# 4              0.823365           -0.363703                 -0.301327
#
#    Label Encoding_Marital_Status  Label Encoding_Loan  Label Encoding_housing  \
# ...

# %% [markdown]
# # Principle Component Analysis

# %%
from sklearn.decomposition import PCA  #importing liabraries
pca=PCA()
fit=pca.fit(X[numerical])  #selecting pca

# %%
import matplotlib.pyplot as plt  #importing liabraries
import numpy as np
plt.figure.figsize=(5,5)  # giving plot size

PC_values = np.arange(pca.n_components_) + 1  # giving PC values
plt.plot(PC_values, pca.explained_variance_ratio_, 'o-', linewidth=2, color='blue')

plt.title('Scree Plot of a Elbow Plot') #giving title
plt.xlabel('Principal Component') #giving x AND y axis names
plt.ylabel('Variance Explained')
plt.show()

# %%
per_var = np.round(pca.explained_variance_ratio_* 100, decimals=1) #showing pca values as plot
labels = ['PC' + str(x) for x in range(1, len(per_var)+1)]
plt.bar(x=range(1,len(per_var)+1), height=per_var, tick_label=labels)
plt.ylabel('Percentage of Explained Variance')#giving x and y label names 
plt.xlabel('Principal Component')
plt.title('Scree Plot')
plt.show()

# %% [markdown]
# # conclusion:
# This data set was raw data and given in 2 files .in the bank data set 10% data taken from the bank full data set.after concating 2 files basic exploration done .There are  no missing values  and outliers and skewness is present .But if we transform dat by log transformation and z score the result may effect .So not done transformations. univarient, bivarient and multi varient analysis done accordingly.Lable encoding done for appropriate columns and feeture engineering also done.PCA done for 14 columns .Kink can be observed at 4th.

# %% [markdown]
# # Report:
# By the analysis most of the members are nearly 20 t0 40 age ,job mostly doing bluecollar job ,most of them are married,taking personal loan and housing loan,most are secondary education ,most of them are not defaulter,in the month of the may loans are more,in nearly all days are having same campaign and loan,very less members subscription taken.
# married, middle agepeople who are having secondary education taking more housing loan and personal.contact type is mostly given cellular.After campaigning also p outcome is very less success and less members subscripted.
